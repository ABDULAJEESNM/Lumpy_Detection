# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Lumpy skin disease data.csv")
data
# Out:
#                x          y region     country reportingDate   cld   dtr  \
# 0      90.380931  22.437184   Asia  Bangladesh     10/9/2020  41.6  12.8
# 1      87.854975  22.986757   Asia       India    20/12/2019  40.5  13.3
# 2      85.279935  23.610181   Asia       India    20/12/2019  27.3  13.6
# 3      81.564510  43.882221   Asia       China    25/10/2019  45.3  12.8
# 4      81.161057  43.834976   Asia       China    25/10/2019  38.8  13.2
# ...          ...        ...    ...         ...           ...   ...   ...
# 24798  20.250000 -16.750000    NaN         NaN           NaN  68.8  12.0
# 24799  20.750000 -16.750000    NaN         NaN           NaN  68.8  11.8
# 24800  21.250000 -16.750000    NaN         NaN           NaN  68.8  11.6
# 24801  21.750000 -16.750000    NaN         NaN           NaN  68.8  11.5
# 24802  22.250000 -16.750000    NaN         NaN           NaN  67.5  11.4
#
#          frs  pet    pre   tmn   tmp   tmx   vap    wet  elevation  \
# ...

# %%
data.head()
# Out:
#            x          y region     country reportingDate   cld   dtr    frs  \
# 0  90.380931  22.437184   Asia  Bangladesh     10/9/2020  41.6  12.8   0.00
# 1  87.854975  22.986757   Asia       India    20/12/2019  40.5  13.3   0.00
# 2  85.279935  23.610181   Asia       India    20/12/2019  27.3  13.6   0.08
# 3  81.564510  43.882221   Asia       China    25/10/2019  45.3  12.8  31.00
# 4  81.161057  43.834976   Asia       China    25/10/2019  38.8  13.2  31.00
#
#    pet   pre   tmn   tmp   tmx   vap   wet  elevation  dominant_land_cover  \
# 0  2.3   1.7  12.7  19.1  25.5  15.7  0.00        147                    2
# 1  2.4   0.0  13.2  19.8  26.5  16.3  0.00        145                    2
# 2  2.3   0.6   9.4  16.2  23.0  13.0  0.98        158                    2
# 3  0.4   8.8 -22.5 -16.1  -9.7   0.9  4.64        178                    2
# 4  0.4  10.5 -20.4 -13.8  -7.2   1.2  1.69        185                    3
#
#    X5_Ct_2010_Da  X5_Bf_2010_Da  lumpy
# ...

# %%
data.tail()
# Out:
#            x      y region country reportingDate   cld   dtr  frs  pet    pre  \
# 24798  20.25 -16.75    NaN     NaN           NaN  68.8  12.0  0.0  3.6  172.0
# 24799  20.75 -16.75    NaN     NaN           NaN  68.8  11.8  0.0  3.6  170.0
# 24800  21.25 -16.75    NaN     NaN           NaN  68.8  11.6  0.0  3.6  167.5
# 24801  21.75 -16.75    NaN     NaN           NaN  68.8  11.5  0.0  3.6  169.5
# 24802  22.25 -16.75    NaN     NaN           NaN  67.5  11.4  0.0  3.7  172.1
#
#         tmn   tmp   tmx   vap    wet  elevation  dominant_land_cover  \
# 24798  17.7  23.7  29.7  22.4  15.60        184                    3
# 24799  18.0  23.9  29.8  23.2  15.70        182                    4
# 24800  18.3  24.1  29.9  23.9  15.87        178                    5
# 24801  18.5  24.2  30.0  24.2  16.30        180                    3
# 24802  18.7  24.4  30.1  24.5  16.67        179                    3
#
#        X5_Ct_2010_Da  X5_Bf_2010_Da  lumpy
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24803 entries, 0 to 24802
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   x                    24803 non-null  float64
#  1   y                    24803 non-null  float64
#  2   region               3039 non-null   object
#  3   country              3039 non-null   object
#  4   reportingDate        3039 non-null   object
#  5   cld                  24803 non-null  float64
#  6   dtr                  24803 non-null  float64
#  7   frs                  24803 non-null  float64
#  8   pet                  24803 non-null  float64
#  9   pre                  24803 non-null  float64
#  10  tmn                  24803 non-null  float64
#  11  tmp                  24803 non-null  float64
#  12  tmx                  24803 non-null  float64
#  13  vap                  24803 non-null  float64
#  14  wet                  24803 non-null  float64
# ...

# %%
data.shape
# Out:
# (24803, 20)

# %%
data.columns
# Out:
# Index(['x', 'y', 'region', 'country', 'reportingDate', 'cld', 'dtr', 'frs',
#        'pet', 'pre', 'tmn', 'tmp', 'tmx', 'vap', 'wet', 'elevation',
#        'dominant_land_cover', 'X5_Ct_2010_Da', 'X5_Bf_2010_Da', 'lumpy'],
#       dtype='object')

# %%
data.nunique()
# Out:
# x                       2292
# y                       2118
# region                     3
# country                   37
# reportingDate            431
# cld                      888
# dtr                      181
# frs                      236
# pet                       76
# pre                     1191
# tmn                      752
# tmp                      763
# tmx                      799
# vap                      271
# wet                     2454
# elevation                171
# dominant_land_cover       12
# X5_Ct_2010_Da          20350
# X5_Bf_2010_Da          14362
# lumpy                      2
# dtype: int64

# %%
data["region"].value_counts()
# Out:
# Europe    2172
# Asia       777
# Africa      90
# Name: region, dtype: int64

# %%
data["lumpy"].value_counts()
# Out:
# 0    21764
# 1     3039
# Name: lumpy, dtype: int64

# %%
data[data.duplicated()]
# Out:
#                x          y  region             country reportingDate   cld  \
# 26     35.465791  32.811608    Asia              Israel    17/09/2019  57.2
# 74     74.871614  54.812720  Europe  Russian Federation    21/08/2019  44.5
# 75     78.096482  54.925270  Europe  Russian Federation    21/08/2019  53.2
# 76     74.871614  54.812720  Europe  Russian Federation    21/08/2019  44.5
# 77     78.096482  54.925270  Europe  Russian Federation    21/08/2019  53.2
# ...          ...        ...     ...                 ...           ...   ...
# 2988  118.316667  24.416667    Asia               China     14-Sep-20  72.4
# 2990  118.427993  24.437691    Asia               China     14-Sep-20  72.4
# 2991  118.427993  24.437691    Asia               China     14-Sep-20  72.4
# 2992  118.427993  24.437691    Asia               China     14-Sep-20  72.4
# 2993  118.427993  24.437691    Asia               China     14-Sep-20  72.4
#
# ...

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (24195, 20)

# %%
data.isnull().sum()
# Out:
# x                          0
# y                          0
# region                 21764
# country                21764
# reportingDate          21764
# cld                        0
# dtr                        0
# frs                        0
# pet                        0
# pre                        0
# tmn                        0
# tmp                        0
# tmx                        0
# vap                        0
# wet                        0
# elevation                  0
# dominant_land_cover        0
# X5_Ct_2010_Da              0
# X5_Bf_2010_Da              0
# lumpy                      0
# dtype: int64

# %%
data['region'].value_counts()
# Out:
# Europe    1809
# Asia       538
# Africa      84
# Name: region, dtype: int64

# %%
sns.displot(data['region'])

# %%
data['lumpy'].value_counts()
# Out:
# 0    21764
# 1     2431
# Name: lumpy, dtype: int64

# %%
sns.displot(data['lumpy'])

# %%
data.describe().T
# Out:
#                        count        mean          std     min         25%  \
# x                    24195.0   80.481799    43.068859 -179.75   46.750000
# y                    24195.0   46.589472    19.376367  -28.75   35.250000
# cld                  24195.0   59.208758    19.502036    0.00   43.400000
# dtr                  24195.0    9.148775     3.006721    2.00    6.800000
# frs                  24195.0   24.230508    11.401773    0.00   23.800000
# pet                  24195.0    0.793151     1.181585    0.00    0.000000
# pre                  24195.0   24.938859    32.389637    0.00    5.700000
# tmn                  24195.0  -16.231928    17.554205  -52.10  -30.600000
# tmp                  24195.0  -11.643703    17.983279  -48.10  -26.000000
# tmx                  24195.0   -7.077462    18.560696  -44.20  -21.200000
# vap                  24195.0    3.644894     4.957740    0.00    0.400000
# wet                  24195.0    8.475692     6.245814    0.00    2.880000
# ...

# %%
lumpy=['21764','2431']
labels=["YES","NO"]
explode=(0.1,0)
plt.pie(lumpy,labels=labels,explode=explode)
plt.show()

# %%
sns.histplot(data=data,x='region',hue='lumpy',kde=True)
# Out:
# <Axes: xlabel='region', ylabel='Count'>

# %%
plt.subplots(figsize=(20, 20))
sns.heatmap(data.corr(),annot=True,fmt='0.2f')
# Out:
# C:\Users\ABDUL AJEES\AppData\Local\Temp\ipykernel_2768\1538364948.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,fmt='0.2f')
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
feature=['x', 'y', 'cld', 'dtr', 'frs',
       'pet', 'pre', 'tmn', 'tmp', 'tmx', 'vap', 'wet', 'elevation',
       'dominant_land_cover', 'X5_Ct_2010_Da', 'X5_Bf_2010_Da', 'lumpy']
x=data[feature]
y=data["lumpy"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()

# %%
log.fit(x_train,y_train)
log_pred=log.predict(x_test)
# Out:
# C:\Users\ABDUL AJEES\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
log_acc=accuracy_score(y_test,log_pred)
print("Logistic Accuracy Score:","{:.2f}%".format(100*log_acc))
# Out:
# Logistic Accuracy Score: 93.76%
